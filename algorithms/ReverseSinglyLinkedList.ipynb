# %% [markdown]
# Reverse a singly linked list.
#
# Example:
#
# Input: 1->2->3->4->5->NULL
# Output: 5->4->3->2->1->NULL
# Follow up:
#
# A linked list can be reversed either iteratively or recursively. Could you implement both?

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def reverseList(self, head):
        """
        :type head: ListNode
        :rtype: ListNode
        """

# %%
# build and print a singly linked list

class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

# build the linked list
nbrNode = 5
myList = ListNode(1)
Head = myList

while myList.val <= 5:
    nodeVal = myList.val
    myList.next = ListNode(nodeVal + 1)
    myList = myList.next
    
    
# print the liked list
myList = Head
strLinkedList = ""

while myList.next != None: 
    strLinkedList += str(myList.val) + '->'
    myList = myList.next
    
print(strLinkedList + 'None')
# Out:
# 1->2->3->4->5->None

# %%
# node class
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None
        
    # print the liked list from the current node    
    def print(self):        
        myList = self
        strLinkedList = ""
        
        while myList.next != None: 
            strLinkedList += str(myList.val) + '->'
            myList = myList.next

        print(strLinkedList + 'None')

        
# reverse the linked list using an array
class Solution:
    def reverseList(self, head):
        
        # edge case
        if head != None:
            
            vals = []
            node = head

            # go through the list and store each el in an array
            while node.next != None:
                vals.append(node.val)
                node = node.next

            # reverse the array 
            vals.reverse()

            # change value of the node
            node = head
            for val in vals:
                node.val = val
                node = node.next

            # don't need to return the list because mutate in place
            
def buildLinkList(nbrNode, firstVal):
    
    head = None
    
    if nbrNode > 0:
    
        # build the linked list
        myList = ListNode(firstVal)
        head = myList

        while myList.val <= nbrNode:
            nodeVal = myList.val
            myList.next = ListNode(nodeVal + 1)
            myList = myList.next
        
    return head

# build linked list
head = buildLinkList(2, 1)
        
# printList
head.print()    
        
# reverse the linked list
solution = Solution()
solution.reverseList(head)

# printList        
head.print()
# Out:
# 1->2->None
# 2->1->None
